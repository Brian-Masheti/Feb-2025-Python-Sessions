# %% [markdown]
# # Data Visualization Basics with matplotlib
#
# ## Introduction to matplotlib
#
# `Matplotlib` is a comprehensive library for creating static, animated, and interactive visualizations in Python. It's often used for visualizing the results of data analysis. The most common form of visualization is through line plots, scatter plots, bar plots, and histograms.

# %% [markdown]
# ## Basic Plotting with matplotlib

# %%
# Import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# # Sample student dataset
# data = {
#     'Student Name': ['Alice', 'Bob', 'Charlie', 'Diana', 'Ethan', 'Fiona', 'George', 'Hannah', 'Ivy', 'Jack'],
#     'Age': [20, 22, 21, 23, 20, 22, 21, 23, 20, 22],
#     'Gender': ['Female', 'Male', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Female', 'Male'],
#     'Grade': ['A', 'B', 'A', 'C', 'B', 'A', 'C', 'B', 'A', 'C'],
#     'Study Hours': [15, 10, 18, 8, 12, 20, 7, 14, 16, 9],
#     'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix', 'Philadelphia', 'San Antonio', 'San Diego', 'Dallas', 'San Jose'],
#     'Attendance (%)': [95, 85, 90, 70, 80, 98, 65, 88, 92, 75]
# }

# # Create a DataFrame
# df = pd.DataFrame(data)

# # Display the first few rows of the updated dataset
# df.head()
# Out:
#   Student Name  Age  Gender Grade  Study Hours         City  Attendance (%)
# 0        Alice   20  Female     A           15     New York              95
# 1          Bob   22    Male     B           10  Los Angeles              85
# 2      Charlie   21    Male     A           18      Chicago              90
# 3        Diana   23  Female     C            8      Houston              70
# 4        Ethan   20    Male     B           12      Phoenix              80

# %% [markdown]
# ### Simple Line Plot:

# %%
# Sample student data
data = {
    'Name': ['Brian', 'Daisy', 'Eve', 'Frank'],
    'Age': [25, 30, 22, 35],
    'Height': [175, 160, 170, 180],
    'Weight': [70, 55, 65, 80],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston'],
    'Country': ['USA', 'USA', 'USA', 'USA']
}

# Create a DataFrame
df = pd.DataFrame(data)

# Plotting Age vs. Name
plt.plot(df['Name'], df['Age'])
plt.xlabel('Name')
plt.ylabel('Age')
plt.title('Name vs Age')
plt.show();

# %% [markdown]
# ### Bar Plot

# %%
# Plotting a bar chart for Age by City
df.groupby('City')['Age'].mean().plot(kind='bar')
plt.xlabel('City')
plt.ylabel('Average Age')
plt.title('Average Age by City')
plt.show();

# %% [markdown]
# ### Histogram

# %%
# Plotting a histogram for Age
df['Age'].plot(kind='hist', bins=10)
plt.xlabel('Age')
plt.title('Age Distribution')
plt.show();

# %% [markdown]
# ### Scatter Plot

# %%
# Plotting a scatter plot of Age vs. City
df.plot(kind='scatter', x='City', y='Age')
plt.title('City vs Age')
plt.show();

# %% [markdown]
# ## Customizing Plots
#
# ### Adding Labels and Title

# %%
# Plotting a box plot for Age by City
df.boxplot(column='Age', by='City')
plt.xlabel('City')
plt.ylabel('Average Age')
plt.title('Average Age by City')
plt.show();

# %% [markdown]
# ### Color and Style

# %%
# Plotting a box plot for Age by City
df.boxplot(column='Age', by='City')
df['Age'].plot(kind='line', 
               color='green', 
               linestyle='--', 
               linewidth=2);
